# %% [markdown]
#     Matrix Creation

# %%
import pandas as pd

filters = {
    "Job Title": ["Title1", "Title2", "Title3"],
    "Location": ["Location1"],
    "Last Update": ["LastUpdate1"],
    "Keyword1": ["Keyword1.1", "Keyword1.2", "Keyword1.3"],
    "Keyword2": ["Keyword2.1", "Keyword2.2", "Keyword2.3"],
}

matrix = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in filters.items()]))
matrix = matrix.fillna("")

print(matrix)
# Out:
#   Job Title   Location  Last Update    Keyword1    Keyword2
# 0    Title1  Location1  LastUpdate1  Keyword1.1  Keyword2.1
# 1    Title2                          Keyword1.2  Keyword2.2
# 2    Title3                          Keyword1.3  Keyword2.3

# %%
import pandas as pd
from datetime import datetime, timedelta

filters = {
    "Job Title": ["Product Manager", "Product Owner", "Technical Product Manager"],
    "Location": ["United States"],
    "Last Update": [(datetime.now() - timedelta(days=30)).strftime("%Y-%m-%d %H:%M:%S")],
    "Keyword1": ["Agile", "Scrum", "Kanban"],
    "Keyword2": ["Roadmap", "Backlog", "Feature Prioritization"],
}

matrix = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in filters.items()]))
matrix = matrix.fillna("")

# %%
matrix.head()
# Out:
#                    Job Title       Location          Last Update Keyword1  \
# 0            Product Manager  United States  2024-12-30 07:00:53    Agile
# 1              Product Owner                                        Scrum
# 2  Technical Product Manager                                       Kanban
#
#                  Keyword2
# 0                 Roadmap
# 1                 Backlog
# 2  Feature Prioritization

# %% [markdown]
# - Since __Location__ and __Last Update__ have no synonyms or variability, they act as "global filters" that must be applied in every search query. So I'll use them at the start of the tree to reduce candidates right away.

# %% [markdown]
# ---

# %% [markdown]
#     API Search function

# %%
import requests
import json

# %%
def run_api_search(filters):
    base_url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"
    
    payload = {
        "experience_deleted": False,
        "active_experience": True,
        "country": filters.get("Location", ""),
        "last_updated_gte": (datetime.now() - timedelta(days=30)).strftime("%Y-%m-%d %H:%M:%S")
    }

    if "Job Title" in filters:
        payload["title"] = filters["Job Title"]
    
    if "Keyword" in filters:
        payload["keyword"] = filters["Keyword"]

    headers = {
        'Content-Type': 'application/json',
        'Authorization': bearer
    }

    all_ids = []
    next_page_after = None

    while True:
        # Modify URL for pagination if needed
        request_url = base_url if not next_page_after else f"{base_url}?after={next_page_after}"

        response = requests.post(request_url, headers=headers, data=json.dumps(payload))

        if response.status_code != 200:
            print(f"Error: API request failed with status {response.status_code}")
            print(f"Response Text: {response.text}")
            break
        
        try:
            response_json = response.json()
            all_ids.extend(response_json)

            # Extract pagination info
            next_page_after = response.headers.get("x-next-page-after")

            # Ensure next_page_after is a valid integer
            if next_page_after and next_page_after.isdigit():
                next_page_after = int(next_page_after)  # Convert to integer
            else:
                break  # Stop if no more pages

        except json.JSONDecodeError:
            print("Error: Invalid JSON response")
            break

    return all_ids, len(all_ids)

# %%
filters = {
    "Location": "United States",
}

list, count = run_api_search(filters)

# %%
count
# Out:
# 2921

# %% [markdown]
# ---

# %% [markdown]
#     Tree Creation

# %%
def create_level_zero(matrix):
    root = {
        "filters": {
            "Location": matrix["Location"].iloc[0],
            "Last Update": matrix["Last Update"].iloc[0]
        },
        "children": []
    }

    return root

# %%
root = create_level_zero(matrix)

# %%
root
# Out:
# {'filters': {'Location': 'United States',
#   'Last Update': '2024-12-30 07:00:53'},
#  'children': []}

# %%
def create_level_one(root, matrix):
    job_titles = matrix["Job Title"].dropna().tolist()
    keyword1_values = matrix["Keyword1"].dropna().tolist()
    keyword2_values = matrix["Keyword2"].dropna().tolist()

    branch1 = {
        "filters": {
            "Location": root["filters"]["Location"],
            "Last Update": root["filters"]["Last Update"],
            "Job Title": f'"{job_titles[0]}"' if job_titles else "",
            "Keyword": f'"{keyword1_values[0]}"' if keyword1_values else ""
        },
        "children": []
    }

    branch2 = {
        "filters": {
            "Location": root["filters"]["Location"],
            "Last Update": root["filters"]["Last Update"],
            "Job Title": f'"{job_titles[0]}"' if job_titles else "",
            "Keyword": f'"{keyword2_values[0]}"' if keyword2_values else ""
        },
        "children": []
    }

    root["children"].extend([branch1, branch2])

# %%
create_level_one(root, matrix)

# %%
root
# Out:
# {'filters': {'Location': 'United States',
#   'Last Update': '2024-12-30 07:00:53'},
#  'children': [{'filters': {'Location': 'United States',
#     'Last Update': '2024-12-30 07:00:53',
#     'Job Title': '"Product Manager"',
#     'Keyword': '"Agile"'},
#    'children': []},
#   {'filters': {'Location': 'United States',
#     'Last Update': '2024-12-30 07:00:53',
#     'Job Title': '"Product Manager"',
#     'Keyword': '"Roadmap"'},
#    'children': []}]}

# %%
for idx, child in enumerate(root["children"], start=1):
    filters = child['filters']  
    ids, num_ids = run_api_search(filters)
    print(f"Level 1 - Child {idx}")
    print(f"Filters Sent to API: {json.dumps(filters, indent=2)}")
    print(f"Num IDs Returned: {num_ids}\n")
# Out:
# Level 1 - Child 1
# Filters Sent to API: {
#   "Location": "United States",
#   "Last Update": "2024-12-30 07:00:53",
#   "Job Title": "\"Product Manager\"",
#   "Keyword": "\"Agile\""
# }
# Num IDs Returned: 13315
#
# Level 1 - Child 2
# Filters Sent to API: {
#   "Location": "United States",
#   "Last Update": "2024-12-30 07:00:53",
#   "Job Title": "\"Product Manager\"",
#   "Keyword": "\"Roadmap\""
# }
# Num IDs Returned: 8576

# %%
def create_level_two(root, matrix):
    job_titles = matrix["Job Title"].dropna().tolist()

    for child in root["children"]:  # Iterate through Level 1 branches
        if len(job_titles) > 1:  # Ensure there are at least 2 job titles
            new_branch = {
                "filters": {
                    "Location": child["filters"]["Location"],
                    "Last Update": child["filters"]["Last Update"],
                    "Job Title": f'"{job_titles[0]}" AND "{job_titles[1]}"',
                    "Keyword": child["filters"]["Keyword"]  # Keep existing keyword filter
                },
                "children": []
            }
            child["children"].append(new_branch)  # Add the new branch to Level 1 child

# %%
create_level_two(root, matrix)

# %%
root
# Out:
# {'filters': {'Location': 'United States',
#   'Last Update': '2024-12-30 07:00:53'},
#  'children': [{'filters': {'Location': 'United States',
#     'Last Update': '2024-12-30 07:00:53',
#     'Job Title': '"Product Manager"',
#     'Keyword': '"Agile"'},
#    'children': [{'filters': {'Location': 'United States',
#       'Last Update': '2024-12-30 07:00:53',
#       'Job Title': '"Product Manager" AND "Product Owner"',
#       'Keyword': '"Agile"'},
#      'children': []}]},
#   {'filters': {'Location': 'United States',
#     'Last Update': '2024-12-30 07:00:53',
#     'Job Title': '"Product Manager"',
#     'Keyword': '"Roadmap"'},
#    'children': [{'filters': {'Location': 'United States',
#       'Last Update': '2024-12-30 07:00:53',
#       'Job Title': '"Product Manager" AND "Product Owner"',
#       'Keyword': '"Roadmap"'},
#      'children': []}]}]}

# %%
for idx, child in enumerate(root["children"], start=1):
    for sub_idx, sub_child in enumerate(child["children"], start=1):
        ids, num_ids = run_api_search(sub_child["filters"])
        print(f"Level 2 - Child {idx}.{sub_idx}")
        print(f"Filters: {json.dumps(sub_child['filters'], indent=2)}")
        print(f"Num IDs Returned: {num_ids}\n")
# Out:
# Level 2 - Child 1.1
# Filters: {
#   "Location": "United States",
#   "Last Update": "2024-12-30 07:00:53",
#   "Job Title": "\"Product Manager\" AND \"Product Owner\"",
#   "Keyword": "\"Agile\""
# }
# Num IDs Returned: 782
#
# Level 2 - Child 2.1
# Filters: {
#   "Location": "United States",
#   "Last Update": "2024-12-30 07:00:53",
#   "Job Title": "\"Product Manager\" AND \"Product Owner\"",
#   "Keyword": "\"Roadmap\""
# }
# Num IDs Returned: 325

# %% [markdown]
# ----

# %%
import json
import requests

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "experience_deleted": False,
    "keyword": '\"performance marketing manager\" OR (Digital Marketer) OR (Paid Media Manager)" AND "(Google Analytics) OR (Google) OR (Attribution Marketing) OR (Attribution)”',
    "location": "Virginia"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
len(response.json())
# Out:
# 1000

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "experience_deleted": False,
    "keyword": '\"performance marketing manager\" OR (Digital Marketer) OR (Paid Media Manager)" AND "(Google Analytics) OR (Google) OR (Attribution Marketing) OR (Attribution)”',
    "location": "Virginia"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

all_ids = []
next_page_after = None

while True:
    # Modify URL for pagination if needed
    request_url = url if not next_page_after else f"{url}?after={next_page_after}"

    response = requests.post(request_url, headers=headers, data=json.dumps(payload))

    if response.status_code != 200:
        print(f"Error: API request failed with status {response.status_code}")
        print(f"Response Text: {response.text}")
        break
    
    try:
        response_json = response.json()
        all_ids.extend(response_json)

        # Extract pagination info
        next_page_after = response.headers.get("x-next-page-after")

        # Ensure next_page_after is a valid integer
        if next_page_after and next_page_after.isdigit():
            next_page_after = int(next_page_after)  # Convert to integer
        else:
            break  # Stop if no more pages

    except json.JSONDecodeError:
        print("Error: Invalid JSON response")
        break

print(f"Total IDs Retrieved: {len(all_ids)}")
# Out:
# Error: API request failed with status 422
# Response Text: {"detail":[{"type":"model_attributes_type","loc":["body"],"msg":"Input should be a valid dictionary or object to extract fields from","input":"{\"experience_deleted\": false, \"keyword\": \"\\\"performance marketing manager\\\" OR (Digital Marketer) OR (Paid Media Manager)\\\" AND \\\"(Google Analytics) OR (Google) OR (Attribution Marketing) OR (Attribution)\\u201d\", \"location\": \"Virginia\"}"}]}
# Total IDs Retrieved: 0

# %%
from datetime import datetime, timedelta
import requests
import json

url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = {
    #"last_updated_gte": (datetime.now() - timedelta(days=30)).strftime("%Y-%m-%d %H:%M:%S"),
    #"experience_deleted": False,
    #"active_experience": True,
    "location": "New York",
    #"experience_title": '((Product Manager) OR (Product Owner) OR (Technical Product Manager))',
    "keyword": '((Agile) OR (Scrum) OR (Kanban)) AND ((Roadmap) OR (Backlog) OR (Feature Prioritization))'
}
# keywords: cap it at 10 total -> 7 synonyms AND 3 seniority

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

all_ids = []
next_page_after = None

while True:
    # Modify URL for pagination if needed
    request_url = url if not next_page_after else f"{url}?after={next_page_after}"

    response = requests.post(request_url, headers=headers, data=json.dumps(payload))

    if response.status_code != 200:
        print(f"Error: API request failed with status {response.status_code}")
        print(f"Response Text: {response.text}")
        break
    
    try:
        response_json = response.json()
        all_ids.extend(response_json)

        # Extract pagination info
        next_page_after = response.headers.get("x-next-page-after")

        # Ensure next_page_after is a valid integer
        if next_page_after and next_page_after.isdigit():
            next_page_after = int(next_page_after)  # Convert to integer
        else:
            break  # Stop if no more pages

    except json.JSONDecodeError:
        print("Error: Invalid JSON response")
        break

print(f"Total IDs Retrieved: {len(all_ids)}")
# Out:
# Total IDs Retrieved: 11788

# %%
all_ids
# Out:
# [3226282,
#  9836166,
#  52724263,
#  56420983,
#  57406051,
#  83449255,
#  85607911,
#  90041848,
#  99013345,
#  99717712,
#  109277262,
#  110883456,
#  119275034,
#  139162117,
#  166236073,
#  190948396,
#  191451426,
#  205300155,
#  212024014,
#  221007616,
#  222326232,
#  247139288,
#  269583625,
#  272329835,
#  273300408,
#  276626210,
#  278076375,
#  280424590,
#  281258824,
#  285482396,
#  287309283,
#  288410079,
#  351782518,
#  352329504,
#  399951145,
#  401292335,
#  422679749,
#  434125833,
#  448452349,
#  457160283,
#  460384340,
#  467001896,
#  469968920,
#  475855688,
#  504984175,
#  529216240,
#  573635424,
#  574418712,
#  577268817,
#  585130624,
#  626686525,
#  634372057,
#  792873049,
#  801426361]

# %%
def collect_employees(ids):
    base_url = 'https://api.coresignal.com/cdapi/v1/professional_network/employee/collect'
    
    headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
    }

    profiles = {}

    for id in ids:
        url = f"{base_url}/{id}"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            profiles[id] = response.json()
        else:
            print("Error", f"\nResponse:{response.text}")
    
    return profiles

# %%
test_ids = [all_ids[0], all_ids[1]]
profiles = collect_employees(test_ids)

# %%
test_ids
# Out:
# [3226282, 9836166]

# %%
print(json.dumps(profiles, indent=2))
# Out:
# {
#   "3226282": {
#     "id": 3226282,
#     "name": "Jessica Campomanes",
#     "first_name": "Jessica",
#     "last_name": "Campomanes",
#     "title": "Performance Marketing Manager at Guardian Life",
#     "user_generated_headline": "Performance Marketing Manager at Guardian Life",
#     "url": "https://www.linkedin.com/in/jcampomanes",
#     "hash": "3441edd8b09a8219437a663a383967fd",
#     "canonical_url": "https://www.linkedin.com/in/jcampomanes",
#     "canonical_hash": "3441edd8b09a8219437a663a383967fd",
#     "member_shorthand_name": "jcampomanes",
#     "member_shorthand_name_hash": "09fd10c875acbe547569203456280e25",
#     "canonical_shorthand_name": "jcampomanes",
#     "canonical_shorthand_name_hash": "09fd10c875acbe547569203456280e25",
#     "created": "2016-07-23 02:34:11",
#     "last_updated": "2024-11-15 22:47:29",
#     "last_updated_ux": 1731710849,
#     "deleted": 0,
#     "last_response_code": 200,
#     "logo_url": "https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2",
#     "summary": "Thoughtful, multi-faceted digital marketing manager with a strong background in paid media and integrated marketing across different channels such as SEM and social. 5+ years of end-to-end experience across strategy, operations, activation, and analytics in an agency setting. Currently executing growth strategies across performance marketing channels in the insurtech space.",
#     "location": "Virginia Beach, Virginia, United States",
#     "country": "United States",
#     "connections": "500+ connections",
#     "connections_count": 65535,
#     "recommendations_count": 0,
#     "industry": "Marketing & Advertising",
#     "outdated": 0,
#     "experience_count": 6,
#     "member_hidden_status_collection": [
#       {
#         "id": 169582289,
#         "member_id": 3226282,
#         "is_hidden": 1,
#         "created": "2024-04-10 00:23:27",
#         "last_updated": "2024-11-15 22:47:29",
#         "deleted": 0
#       }
#     ],
#     "member_experience_collection": [
#       {
#         "id": 1661860325408,
#         "member_id": 3226282,
#         "title": "Performance Marketing Manager, Individual Markets",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "October 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2024-11-15 22:47:28",
#         "deleted": 0,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 3777267863,
#         "member_id": 3226282,
#         "title": "Digital Marketing Manager, DTC",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "July 2022",
#         "date_to": "October 2022",
#         "duration": "4 months",
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 0,
#         "order_in_profile": 2,
#         "company_id": 2539187
#       },
#       {
#         "id": 3777267864,
#         "member_id": 3226282,
#         "title": "Marketing Manager",
#         "location": null,
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "May 2021",
#         "date_to": "June 2022",
#         "duration": "1 year 2 months",
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 0,
#         "order_in_profile": 3,
#         "company_id": 11839799
#       },
#       {
#         "id": 3777267865,
#         "member_id": 3226282,
#         "title": "Lead Media Strategist, Paid Media",
#         "location": null,
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "February 2020",
#         "date_to": "May 2021",
#         "duration": "1 year 4 months",
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 0,
#         "order_in_profile": 4,
#         "company_id": 11839799
#       },
#       {
#         "id": 3777267866,
#         "member_id": 3226282,
#         "title": "Account Supervisor, Paid Media",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": "January 2020",
#         "duration": "2 years 6 months",
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 0,
#         "order_in_profile": 5,
#         "company_id": 11839799
#       },
#       {
#         "id": 3777267867,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": "Baltimore, Maryland",
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": "August 2017",
#         "duration": "5 months",
#         "description": null,
#         "created": "2023-11-04 01:46:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 0,
#         "order_in_profile": 6,
#         "company_id": 2848487
#       },
#       {
#         "id": 1275493373,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": "Virginia Beach, Virginia",
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">- Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>- Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>- Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2018-10-25 20:00:18",
#         "last_updated": "2019-02-13 04:25:35",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 1275493370,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": "Baltimore, Maryland",
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": "August 2017",
#         "duration": "5 months",
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">- Perform special projects, including competitive case studies, background research, and preliminary media and promotion work for medium to large size companies including McCormick &amp; Co., Hair Cuttery, and Sears Canada. <br>- Input and update internal and client data into excel to provide reporting for multiple users.<br>- Continuous analyzing of competitive and industry trend information for multiple client projects. <br></p>",
#         "created": "2018-10-25 20:00:18",
#         "last_updated": "2019-02-13 04:25:35",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 1275493367,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">Clients: United Way, Loyola University, Deutsche Asset Management, Drexel University</p>",
#         "created": "2018-10-25 20:00:18",
#         "last_updated": "2019-02-13 04:25:35",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 11839799
#       },
#       {
#         "id": 1264710163,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": "Virginia Beach, Virginia",
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">- Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>- Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>- Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2018-10-19 20:05:13",
#         "last_updated": "2018-10-25 20:00:18",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 1264710162,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": "Baltimore, Maryland",
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": "August 2017",
#         "duration": "5 months",
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">- Perform special projects, including competitive case studies, background research, and preliminary media and promotion work for medium to large size companies including McCormick &amp; Co., Hair Cuttery, and Sears Canada. <br>- Input and update internal and client data into excel to provide reporting for multiple users.<br>- Continuous analyzing of competitive and industry trend information for multiple client projects. <br></p>",
#         "created": "2018-10-19 20:05:13",
#         "last_updated": "2018-10-25 20:00:18",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 1264710161,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">Clients: United Way, Loyola University, Deutsche Asset Management, Drexel University</p>",
#         "created": "2018-10-19 20:05:13",
#         "last_updated": "2018-10-25 20:00:18",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 11839799
#       },
#       {
#         "id": 1261339035,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"item-body--margin-left item-body--title-small\">Clients: United Way, Loyola University, Deutsche Asset Management, Drexel University</p>",
#         "created": "2018-10-13 11:49:10",
#         "last_updated": "2018-10-19 20:05:13",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 11839799
#       },
#       {
#         "id": 1002734709,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": "Virginia Beach, Virginia",
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>- Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>- Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2018-06-16 20:22:07",
#         "last_updated": "2018-10-19 20:05:13",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 1002734707,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono)",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": "August 2017",
#         "duration": "1 year",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Conducted a successful SEO audit and link-building campaign for San Francisco Technology startup (Birdi) to increase the website's credibility and drive traffic.<br>- Optimized segment growth by transforming marketing strategy, including message and content creation for local small businesses in Maryland and Virginia.<br>- Organize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.</p>",
#         "created": "2018-06-16 20:22:07",
#         "last_updated": "2019-02-13 04:25:35",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 1002734705,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": "Baltimore, Maryland",
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": "August 2017",
#         "duration": "5 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Perform special projects, including competitive case studies, background research, and preliminary media and promotion work for medium to large size companies including McCormick &amp; Co., Hair Cuttery, and Sears Canada. <br>- Input and update internal and client data into excel to provide reporting for multiple users.<br>- Continuous analyzing of competitive and industry trend information for multiple client projects. <br></p>",
#         "created": "2018-06-16 20:22:06",
#         "last_updated": "2018-10-19 20:05:13",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 1002734702,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">Clients: Loyola Maryland, Deutsche Asset Management, Drexel</p>",
#         "created": "2018-06-16 20:22:06",
#         "last_updated": "2018-10-13 11:49:10",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 11839799
#       },
#       {
#         "id": 868078729,
#         "member_id": 3226282,
#         "title": "Jr. Digital Marketing Specialist (Seasonal)",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": "January 2017",
#         "duration": "4 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns.<br>- Generated leads and maintained clients to develop brand awareness while handling external online marketing campaigns and programs.<br>- Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.</p>",
#         "created": "2018-02-25 10:04:09",
#         "last_updated": "2019-02-13 04:25:35",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 868078728,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono) and Events Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": "August 2017",
#         "duration": "1 year",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Conducted a successful SEO audit and link-building campaign for San Francisco Technology startup (Birdi) to increase the website's credibility and drive traffic.<br>- Optimized segment growth by transforming marketing strategy, including message and content creation for local small businesses in Maryland and Virginia.<br>- Organize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.</p>",
#         "created": "2018-02-25 10:04:09",
#         "last_updated": "2018-06-16 20:22:06",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 868078727,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": null,
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": "August 2017",
#         "duration": "5 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Perform special projects, including competitive case studies, background research, and preliminary media and promotion work for medium to large size companies including McCormick &amp; Co., Hair Cuttery, and Sears Canada. <br>- Input and update internal and client data into excel to provide reporting for multiple users.<br>- Continuous analyzing of competitive and industry trend information for multiple client projects. <br></p>",
#         "created": "2018-02-25 10:04:09",
#         "last_updated": "2018-06-16 20:22:06",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 814603007,
#         "member_id": 3226282,
#         "title": "Jr. Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": "January 2017",
#         "duration": "4 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns.<br>- Generated leads and maintained clients to develop brand awareness while handling external online marketing campaigns and programs.<br>- Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.</p>",
#         "created": "2017-11-26 00:34:37",
#         "last_updated": "2018-02-25 10:04:09",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 814603006,
#         "member_id": 3226282,
#         "title": "Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive-llc-",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2017-11-26 00:34:37",
#         "last_updated": "2018-06-16 20:22:06",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 3828301
#       },
#       {
#         "id": 734777084,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": null,
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>- Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>- Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2017-08-01 00:23:24",
#         "last_updated": "2018-06-16 20:22:06",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 734777083,
#         "member_id": 3226282,
#         "title": "Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": "January 2017",
#         "duration": "4 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns.<br>- Generated leads and maintained clients to develop brand awareness while handling external online marketing campaigns and programs.<br>- Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.</p>",
#         "created": "2017-08-01 00:23:24",
#         "last_updated": "2017-11-26 00:34:37",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 734777082,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono) and Events Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Conducted a successful SEO audit and link-building campaign for San Francisco Technology startup (Birdi) to increase the website's credibility and drive traffic.<br>- Optimized segment growth by transforming marketing strategy, including message and content creation for local small businesses in Maryland and Virginia.<br>- Organize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.</p>",
#         "created": "2017-08-01 00:23:24",
#         "last_updated": "2018-02-25 10:04:09",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 734777081,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": null,
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Perform special projects, including competitive case studies, background research, and preliminary media and promotion work for medium to large size companies including McCormick &amp; Co., Hair Cuttery, and Sears Canada. <br>- Input and update internal and client data into excel to provide reporting for multiple users.<br>- Continuous analyzing of competitive and industry trend information for multiple client projects. <br></p>",
#         "created": "2017-08-01 00:23:24",
#         "last_updated": "2018-02-25 10:04:09",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 652948591,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": null,
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "- Input and analyzed data related to ongoing projects within the strategic initiatives team. - Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization. - Performed multiple literature reviews on topics related to strategic initiatives research projects.",
#         "created": "2017-06-06 16:24:33",
#         "last_updated": "2017-08-01 00:23:24",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 652948590,
#         "member_id": 3226282,
#         "title": "Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns. - Generated leads and maintained clients to develop brand awareness while handling external online marketing campaigns and programs. - Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.",
#         "created": "2017-06-06 16:24:33",
#         "last_updated": "2017-08-01 00:23:24",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 652948589,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono) and Events Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "- Conducted a successful SEO audit and link-building campaign for San Francisco Technology startup (Birdi) to increase the website's credibility and drive traffic. - Optimized segment growth by transforming marketing strategy, including message and content creation for local small businesses in Maryland and Virginia. - Organize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.",
#         "created": "2017-06-06 16:24:33",
#         "last_updated": "2017-08-01 00:23:24",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 652948588,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": null,
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "- Gather and organize product, market and competitive information for existing and potential clients. - Work closely with creative and media strategy development and assist in social media strategy and content development. - Draft internal paperwork documenting client approvals and changes.",
#         "created": "2017-06-06 16:24:33",
#         "last_updated": "2017-08-01 00:23:24",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 624815599,
#         "member_id": 3226282,
#         "title": "Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns.<br>- Generated leads and maintained clients to develop brand awareness while handling external online marketing campaigns and programs.<br>- Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.</p>",
#         "created": "2017-04-25 04:36:09",
#         "last_updated": "2017-06-06 16:24:33",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 624815598,
#         "member_id": 3226282,
#         "title": "Account Management Intern",
#         "location": null,
#         "company_name": "TBC",
#         "company_url": "https://www.linkedin.com/company/tbc",
#         "date_from": "April 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Gather and organize product, market and competitive information for existing and potential clients.<br>- Work closely with creative and media strategy development and assist in social media strategy and content development.<br> - Draft internal paperwork documenting client approvals and changes.</p>",
#         "created": "2017-04-25 04:36:09",
#         "last_updated": "2017-06-06 16:24:33",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 2848487
#       },
#       {
#         "id": 606988336,
#         "member_id": 3226282,
#         "title": "Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Streamlined operative performance by implementing creative marketing strategies, including email-marketing and social media campaigns.<br>- Generated leads and maintained clients to develop brand awareness while handling internal and external online marketing campaigns and programs.<br>- Collaborated with web development team to strengthen navigation, user experience, online brand positioning, and advertisement success.</p>",
#         "created": "2017-03-21 01:48:11",
#         "last_updated": "2017-04-25 04:36:09",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 606988335,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono) and Events Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">- Conducted a successful SEO audit and link-building campaign for San Francisco Technology startup (Birdi) to increase the website's credibility and drive traffic.<br>- Optimized segment growth by transforming marketing strategy, including message and content creation for local small businesses in Maryland and Virginia.<br>- Organize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.</p>",
#         "created": "2017-03-21 01:48:11",
#         "last_updated": "2017-06-06 16:24:33",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 586401521,
#         "member_id": 3226282,
#         "title": "Marketing Consultant (Pro Bono) and Events Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">\u2022\tOrganize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.<br>\u2022\tPerform pro-bono marketing strategy consulting services for San Francisco start-up Birdi, smart air monitor company; collaborate closely with clients to grow revenue and bring in more customers.<br>\u2022\tSupervise membership system and improve association development and reputation.<br></p>",
#         "created": "2017-01-28 18:59:44",
#         "last_updated": "2017-03-21 01:48:12",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 586401520,
#         "member_id": 3226282,
#         "title": "Digital Marketing Specialist",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "The Light Brigade LLC",
#         "company_url": null,
#         "date_from": "October 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">-  Implement marketing strategies to attract site traffic, convert traffic into new leads for the business, and nurture leads to close into customers.<br>- Consult on digital marketing strategies through management of social media presence and webinar program plans to shape brand image and increase customer base and loyalty. <br>- Coordinate organization\u2019s online promotion strategies through email marketing and social network plans; assisted in website optimization re-design.<br><br></p>",
#         "created": "2017-01-28 18:59:44",
#         "last_updated": "2017-03-21 01:48:12",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 523095061,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": null,
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">- Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>- Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>- Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2016-11-10 04:46:43",
#         "last_updated": "2017-06-06 16:24:33",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 523095060,
#         "member_id": 3226282,
#         "title": "Desk / Archives Assistant",
#         "location": null,
#         "company_name": "University of Virginia Music Library",
#         "company_url": "https://www.linkedin.com/company/university-of-virginia",
#         "date_from": "August 2015",
#         "date_to": "May 2016",
#         "duration": "10 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">Conducted research and aided in the development of an international program strategy and design for a newly implemented campaign for the organization\u2019s upcoming medical missions.<br>Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>Performed multiple literature reviews on topics related to strategic initiatives research projects.</p>",
#         "created": "2016-11-10 04:46:43",
#         "last_updated": "2017-01-28 18:59:45",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 26441392
#       },
#       {
#         "id": 523095059,
#         "member_id": 3226282,
#         "title": "Marketing Events Lead; Human Resources Lead",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "Carey Marketing Association",
#         "company_url": null,
#         "date_from": "September 2016",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"description\" data-section=\"currentPositions\">\u2022\tOrganize events to create value and promote professional development for Johns Hopkins Business School students through career treks, case competitions, and networking events.<br>\u2022\tPerform pro-bono marketing strategy consulting services for San Francisco start-up Birdi, smart air monitor company; collaborate closely with clients to grow revenue and bring in more customers.<br>\u2022\tSupervise membership system and improve association development and reputation.<br></p>",
#         "created": "2016-11-10 04:46:43",
#         "last_updated": "2017-01-28 18:59:45",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": null
#       },
#       {
#         "id": 3997470,
#         "member_id": 3226282,
#         "title": "Strategic Initiatives Intern",
#         "location": null,
#         "company_name": "Operation Smile",
#         "company_url": "https://www.linkedin.com/company/operation-smile",
#         "date_from": "June 2015",
#         "date_to": "August 2015",
#         "duration": "3 months",
#         "description": "<p class=\"description\" data-section=\"pastPositions\">Input and analyzed data related to ongoing projects within the strategic initiatives team.<br>Conducted research that helped with the development of the international program strategy and design for new campaigns of medical missions of the organization.<br>Performed multiple literature reviews on topics related to strategic initiatives research projects.<br></p>",
#         "created": "2016-07-23 02:34:11",
#         "last_updated": "2016-11-10 04:46:43",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 5935978
#       },
#       {
#         "id": 3997469,
#         "member_id": 3226282,
#         "title": "Desk / Archives Assistant",
#         "location": null,
#         "company_name": "University of Virginia Music Library",
#         "company_url": "https://www.linkedin.com/company/university-of-virginia",
#         "date_from": "August 2015",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2016-07-23 02:34:11",
#         "last_updated": "2016-11-10 04:46:43",
#         "deleted": 1,
#         "order_in_profile": 0,
#         "company_id": 26441392
#       },
#       {
#         "id": 3544484865,
#         "member_id": 3226282,
#         "title": "Performance Marketing Manager, Individual Markets",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "October 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2023-06-21 12:07:57",
#         "last_updated": "2023-11-04 01:46:57",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 3415644137,
#         "member_id": 3226282,
#         "title": "Performance Marketing Manager, Individual Markets",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "July 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2023-04-29 14:11:29",
#         "last_updated": "2023-06-21 12:07:57",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 3391259165,
#         "member_id": 3226282,
#         "title": "Digital Marketing Manager, Growth",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "July 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2023-04-10 19:51:01",
#         "last_updated": "2023-04-29 14:11:29",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 3217618018,
#         "member_id": 3226282,
#         "title": "Digital Marketing Manager",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "July 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2022-11-19 00:06:45",
#         "last_updated": "2023-04-10 19:51:01",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 3098456714,
#         "member_id": 3226282,
#         "title": "Digital Marketing Manager (Guardian Direct)",
#         "location": "New York, New York, United States",
#         "company_name": "Guardian Life",
#         "company_url": "https://www.linkedin.com/company/the-guardian-life-insurance-company-of-america_164085",
#         "date_from": "July 2022",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2022-08-13 12:36:02",
#         "last_updated": "2022-11-19 00:06:45",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 2539187
#       },
#       {
#         "id": 2800560862,
#         "member_id": 3226282,
#         "title": "Marketing Manager",
#         "location": null,
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "May 2021",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2021-10-06 21:31:14",
#         "last_updated": "2022-08-13 12:36:02",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 11839799
#       },
#       {
#         "id": 2398370702,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "Clients: United Way, Loyola University, Deutsche Asset Management, Drexel UniversityLead competitive and industry trend analysis projects, devise lead nurture and site traffic growth strategies, and develop search intent PPC plans and optimizations for leading universities and organizations including Johns Hopkins, United Way, and Deutsche Bank in both individual and team settings. Develop strategy and financial modeling for a variety of campaigns such as traditional marketing, email and social media. Nurture client relationships and complete multiple client-facing deliverables and strategic reports to shape growth tactics and implementation.",
#         "created": "2020-07-02 18:59:05",
#         "last_updated": "2021-10-06 21:31:14",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 11839799
#       },
#       {
#         "id": 2118700184,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"sr-only\">Clients: United Way, Loyola University, Deutsche Asset Management, Drexel University<br><br>Lead competitive and industry trend analysis projects, devise lead nurture and site traffic growth strategies, and develop search intent PPC plans and optimizations for leading universities and organizations including Johns Hopkins, United Way, and Deutsche Bank in both individual and team settings. Develop strategy and financial modeling for a variety of campaigns such as traditional marketing, email and social media. Nurture client relationships and complete multiple client-facing deliverables and strategic reports to shape growth tactics and implementation.</p>",
#         "created": "2019-12-29 11:27:42",
#         "last_updated": "2020-07-02 18:59:05",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 11839799
#       },
#       {
#         "id": 2032065551,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": null,
#         "created": "2019-11-08 22:17:50",
#         "last_updated": "2019-12-29 11:27:42",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 11839799
#       },
#       {
#         "id": 1865694963,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
#         "description": "<p class=\"position-body__description\" data-section=\"currentPositions\">Clients: United Way, Loyola University, Deutsche Asset Management, Drexel University<br><br>Lead competitive and industry trend analysis projects, devise lead nurture and site traffic growth strategies, and develop search intent PPC plans and optimizations for leading universities and organizations including Johns Hopkins, United Way, and Deutsche Bank in both individual and team settings. Develop strategy and financial modeling for a variety of campaigns such as traditional marketing, email and social media. Nurture client relationships and complete multiple client-facing deliverables and strategic reports to shape growth tactics and implementation.</p>",
#         "created": "2019-06-28 09:33:12",
#         "last_updated": "2019-11-08 22:17:50",
#         "deleted": 1,
#         "order_in_profile": 1,
#         "company_id": 11839799
#       },
#       {
#         "id": 1561613098,
#         "member_id": 3226282,
#         "title": "Media Account Supervisor",
#         "location": "Baltimore, Maryland Area",
#         "company_name": "idfive",
#         "company_url": "https://www.linkedin.com/company/idfive",
#         "date_from": "August 2017",
#         "date_to": null,
#         "duration": null,
# ...
#         "deleted": 1
#       },
#       {
#         "id": 12710754411,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/jessica-fritz",
#         "title": null,
#         "location": null,
#         "created": "2020-09-25 04:40:39",
#         "last_updated": "2021-01-30 00:16:06",
#         "deleted": 1
#       },
#       {
#         "id": 12710754409,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/alexdimattina",
#         "title": null,
#         "location": null,
#         "created": "2020-09-25 04:40:39",
#         "last_updated": "2021-01-30 00:16:06",
#         "deleted": 1
#       },
#       {
#         "id": 12710754407,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/youngshin-chun",
#         "title": null,
#         "location": null,
#         "created": "2020-09-25 04:40:39",
#         "last_updated": "2021-01-30 00:16:06",
#         "deleted": 1
#       },
#       {
#         "id": 12710754404,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/sussie-prem-233439183",
#         "title": null,
#         "location": null,
#         "created": "2020-09-25 04:40:39",
#         "last_updated": "2021-01-30 00:16:06",
#         "deleted": 1
#       },
#       {
#         "id": 12710754402,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/matthew-russell-46752370",
#         "title": null,
#         "location": null,
#         "created": "2020-09-25 04:40:39",
#         "last_updated": "2021-01-30 00:16:06",
#         "deleted": 1
#       },
#       {
#         "id": 11608379183,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/jenna-k-davis-?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379182,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/kristy-elkins-68331219a?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379181,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/delaney-guinn-0b9b00168?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379180,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/ryan-burgess-21b9b040?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379179,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/jake-norcini-334558141?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379178,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/jlowden?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379177,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/aliciabertrand?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11608379176,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/shadman-shaikh-32437894?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-05-03 12:56:08",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11208468898,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/adriannagrigorian?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468897,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/yosanmascio?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468896,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/siena-di-roma?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468895,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/ashley-woods722?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468894,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/triciasylvia?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468893,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/carley-cook-923666101?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468892,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/amanda-lewullis-776745142?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468889,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/kaitlyn-schaefer?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468887,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/megan-boyles?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468885,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/nataliemoore10?trk=public_profile_similar-profiles_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468883,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/todd-franks-616a7110?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468881,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/taylor-perdue-34abb0182?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468879,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/meghan-henry-192790124?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468877,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/karinanyman?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468875,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/mckenzimacdowall?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468873,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/angelynndo?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468870,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/benjamin-calacci-bb468416?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 11208468869,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/kristenbradley2?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 11208468867,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/pratibha-pandeybit?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2020-03-18 10:00:28",
#         "last_updated": "2020-05-03 12:56:07",
#         "deleted": 1
#       },
#       {
#         "id": 8981832959,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/kaylafranco?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-12 22:52:04",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8981832950,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/reanna-reyes?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-12 22:52:04",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457965,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/shelby-chenault-882295193?trk=public_profile_samename_profile_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 8870457945,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/shelby-chenault-b9599a104?trk=public_profile_samename_profile_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 8870457927,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/madeleine-hovis?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457910,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/azitapeters?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457893,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/rsdorsey?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457882,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/kylierudder?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457870,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/sylvie-job?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457844,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/jessica-fritz?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-06-03 17:44:25",
#         "deleted": 1
#       },
#       {
#         "id": 8870457825,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/leahhendershot?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       },
#       {
#         "id": 8870457777,
#         "member_id": 9836166,
#         "url": "https://www.linkedin.com/in/rachel-higgs?trk=public_profile_browsemap_profile-result-card_result-card_full-click",
#         "title": null,
#         "location": null,
#         "created": "2019-11-06 06:42:33",
#         "last_updated": "2020-03-18 10:00:28",
#         "deleted": 1
#       }
#     ]
#   }
# }
