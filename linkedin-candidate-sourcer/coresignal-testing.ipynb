# %%
import requests
import json

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "keyword": "omnistudio AND vlocity AND (lwc OR lightning web components) AND apex",
    "experience_deleted": False,
    "active_experience": False,
    "country": "(United States)"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': ''
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [8828671,18122068,48978925,58393750,177503176,249352306,266934915,340767897,360703290,390594326,412289388,445624941,465836447,514658024,561839790,576532285,612325767,619269089,669677216,736374192,743909824,781311880,787652973,791303676,792227969,796912923,801054297]

# %%
numbers_list = list(map(int, response.text.strip("[]").split(",")))
print(numbers_list)
# Out:
# [8828671, 18122068, 48978925, 58393750, 177503176, 249352306, 266934915, 340767897, 360703290, 390594326, 412289388, 445624941, 465836447, 514658024, 561839790, 576532285, 612325767, 619269089, 669677216, 736374192, 743909824, 781311880, 787652973, 791303676, 792227969, 796912923, 801054297]

# %%
len(numbers_list)
# Out:
# 27

# %%
numbers_list[0]
# Out:
# 8828671

# %%
url = f"https://api.coresignal.com/cdapi/v1/professional_network/employee/collect/{numbers_list[0]}"

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
    }

profile = requests.request("GET", url, headers=headers)

print(profile.text)
# Out:
# {"id":8828671,"name":"Sasank Uppalapati","first_name":"Sasank","last_name":"Uppalapati","title":"Senior Salesforce Developer | 4X Certified | Salesforce Developer | Solution Consultant.","user_generated_headline":"Senior Salesforce Developer | 4X Certified | Salesforce Developer | Solution Consultant.","url":"https://www.linkedin.com/in/sasank-uppalapati-4a7a201a","hash":"b0b98e33facf545e832897cfff092edd","canonical_url":"https://www.linkedin.com/in/sasank-uppalapati-4a7a201a","canonical_hash":"b0b98e33facf545e832897cfff092edd","member_shorthand_name":"sasank-uppalapati-4a7a201a","member_shorthand_name_hash":"80f0b203af2aae43c93277da020feb7f","canonical_shorthand_name":"sasank-uppalapati-4a7a201a","canonical_shorthand_name_hash":"80f0b203af2aae43c93277da020feb7f","created":"2016-07-26 00:37:12","last_updated":"2025-01-05 05:00:28","last_updated_ux":1736053228,"deleted":0,"last_response_code":200,"logo_url":"https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2","summary":"•
# ...

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "keyword": "omnistudio AND vlocity AND (lwc OR lightning web components) AND apex",
    "experience_deleted": False,
    "active_experience": False,
    "country": "(United States)"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [18122068,48978925,58393750,142481793,304369504,340767897,367505273,390594326,412121836,414465630,415326652,427251947,445624941,465836447,471035760,478980536,499780416,514658024,579458369,615561540,635163814,635981070,736374192,744666145,750374966,752994905,781311880,782502466,787652973,791303676,792012856,792227969,796912923,797714074,801054297]

# %%
numbers_list = list(map(int, response.text.strip("[]").split(",")))
print(numbers_list)
# Out:
# [18122068, 48978925, 58393750, 142481793, 304369504, 340767897, 367505273, 390594326, 412121836, 414465630, 415326652, 427251947, 445624941, 465836447, 471035760, 478980536, 499780416, 514658024, 579458369, 615561540, 635163814, 635981070, 736374192, 744666145, 750374966, 752994905, 781311880, 782502466, 787652973, 791303676, 792012856, 792227969, 796912923, 797714074, 801054297]

# %%
len(numbers_list)
# Out:
# 35

# %% [markdown]
# ---

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "experience_deleted": False,
    "active_experience": False,
    "location": "Virginia",
    "keyword": "pricing AND strategy AND b2b AND model AND financial"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [24328227,132225794,387185243,788781003]

# %%
numbers_list = list(map(int, response.text.strip("[]").split(",")))
print(numbers_list)
# Out:
# [24328227, 132225794, 387185243, 788781003]

# %%
url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "keyword": "omnistudio AND vlocity AND salesforce",
    "experience_deleted": False,
    "active_experience": False,
    "country": "(United States)"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [8828671,18122068,48978925,58393750,84148163,85562918,95394435,118881867,129921482,142855630,153112711,169415122,174243312,175264294,177503176,179212286,181213875,188607792,195890620,198637769,249352306,266934915,267976994,268065690,279058772,304369504,326617680,336021185,336507100,336840064,340767897,347226869,356007814,360703290,367505273,380668752,390594326,391542088,392975552,394789379,410241728,412121836,412289388,414465630,415326652,427251947,429001941,440056024,443336712,445624941,451283353,453871464,465830557,465836447,471035760,472082211,472299404,473717966,476224709,478980536,479617779,483911131,492326957,499780416,505995688,514658024,522343709,523670573,524806662,561839790,571726673,572881349,576249891,576532285,579458369,596806035,612325767,612328640,615561540,619269089,635505229,635981070,636533782,637533354,638107148,645870212,648977312,669677216,683525728,684057671,684500617,684923112,736374192,742405890,743909824,743934875,744666145,747074417,750374966,750655851,75299
# ...

# %%
numbers_list = list(map(int, response.text.strip("[]").split(",")))
print(numbers_list)
# Out:
# [8828671, 18122068, 48978925, 58393750, 84148163, 85562918, 95394435, 118881867, 129921482, 142855630, 153112711, 169415122, 174243312, 175264294, 177503176, 179212286, 181213875, 188607792, 195890620, 198637769, 249352306, 266934915, 267976994, 268065690, 279058772, 304369504, 326617680, 336021185, 336507100, 336840064, 340767897, 347226869, 356007814, 360703290, 367505273, 380668752, 390594326, 391542088, 392975552, 394789379, 410241728, 412121836, 412289388, 414465630, 415326652, 427251947, 429001941, 440056024, 443336712, 445624941, 451283353, 453871464, 465830557, 465836447, 471035760, 472082211, 472299404, 473717966, 476224709, 478980536, 479617779, 483911131, 492326957, 499780416, 505995688, 514658024, 522343709, 523670573, 524806662, 561839790, 571726673, 572881349, 576249891, 576532285, 579458369, 596806035, 612325767, 612328640, 615561540, 619269089, 635505229, 635981070, 636533782, 637533354, 638107148, 645870212, 648977312, 669677216, 683525728, 684057671, 684500617, 6849
# ...

# %%
len(numbers_list)
# Out:
# 113

# %%
import requests
import json

url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "experience_deleted": False,
    "active_experience": False,
    "keyword": """("secret clearance" OR "secret cleared") AND ("salesforce developer")""",
    "country": "(United States)"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [26506989,239971202,501557013,537374847]

# %%
import requests
import json

url = "https://api.coresignal.com/cdapi/v1/professional_network/employee/search/filter"

payload = json.dumps({
    "experience_deleted": False,
    "active_experience": False,
    "keyword": """("secret clearance" OR "secret cleared") OR ("salesforce developer")""",
    "country": "(United States)",
    "title": "(Salesforce Developer)"
})

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# [794663,1363536,1467738,1595764,1651215,1759162,2506162,2598374,3553105,3778551,3926059,4330465,4406438,4773182,7531776,8120819,8272229,8828671,8837268,8939436,9215540,9221800,9356568,9374288,9374866,9509060,10313006,10375527,12115878,12474861,16070322,16613627,16767795,16800530,17128851,17146619,17176688,17177215,17350664,17428871,17575407,18122068,18181260,18686542,18883358,19239422,19291526,19367633,19621704,20658858,20662700,21054855,22858807,22883796,22902899,23855138,24004738,24156533,24845800,25117026,25146393,25273266,26452726,27120297,27506382,27578363,27753357,27820267,27990422,28082766,29070256,29726103,30589623,31130021,31923894,32692946,32797182,33530451,35045397,35450474,35734876,35782546,36251591,36927352,36935251,36953062,37163377,37639772,38124784,38367258,38618682,39549904,39858509,40188873,40514540,40815727,41527130,41611141,42190596,42892202,42970038,43009075,43161371,43576773,44430999,45034652,45179535,46105637,46842445,46925722,46973754,47514341,49108821,4935212
# ...

# %%
numbers_list = list(map(int, response.text.strip("[]").split(",")))
print(numbers_list)
# Out:
# [794663, 1363536, 1467738, 1595764, 1651215, 1759162, 2506162, 2598374, 3553105, 3778551, 3926059, 4330465, 4406438, 4773182, 7531776, 8120819, 8272229, 8828671, 8837268, 8939436, 9215540, 9221800, 9356568, 9374288, 9374866, 9509060, 10313006, 10375527, 12115878, 12474861, 16070322, 16613627, 16767795, 16800530, 17128851, 17146619, 17176688, 17177215, 17350664, 17428871, 17575407, 18122068, 18181260, 18686542, 18883358, 19239422, 19291526, 19367633, 19621704, 20658858, 20662700, 21054855, 22858807, 22883796, 22902899, 23855138, 24004738, 24156533, 24845800, 25117026, 25146393, 25273266, 26452726, 27120297, 27506382, 27578363, 27753357, 27820267, 27990422, 28082766, 29070256, 29726103, 30589623, 31130021, 31923894, 32692946, 32797182, 33530451, 35045397, 35450474, 35734876, 35782546, 36251591, 36927352, 36935251, 36953062, 37163377, 37639772, 38124784, 38367258, 38618682, 39549904, 39858509, 40188873, 40514540, 40815727, 41527130, 41611141, 42190596, 42892202, 42970038, 43009075, 4316
# ...

# %%
len(numbers_list)
# Out:
# 1000
